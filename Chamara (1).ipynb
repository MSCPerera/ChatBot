# %%
# INstall the necessary packages
# !pip install langchain -qU
# !pip install langchain-openai -qU
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.5 MB/s eta 0:00:00

# %%
# Import necessary libraries
import os
from google.colab import userdata

# %% [markdown]
# Initialize OpenAI LLM

# %%
from langchain_openai import ChatOpenAI

# Set OpenAI API Key
os.environ["OPENAI_API_KEY"] = "ChatBot"

# Initialize the ChatOpenAI model
llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0
    )

# %% [markdown]
# Initialize Promt Template

# %%
from langchain_core.prompts import ChatPromptTemplate

# Create a promt template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an intelligent chatbot. Answer the following question."),
        ("user", "{question}")
    ]
)

# %% [markdown]
# Initialize Output Parser

# %%
from langchain_core.output_parsers import StrOutputParser

# Create the string output parser
parser = StrOutputParser()

# %%
# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.6.0-1ubuntu1.3_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1.3) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1.3) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for libarchive: filename=libarchive-0.4.7-py3-none-any.whl size=31631 sha256=8937d094a5e085f68b41bb00992668151458195134a3f1b5aa42ecefd8e67249
#   Stored in directory: /root/.cache/pip/wheels/32/98/bd/4893d6923dd027f455b250367d402bfd69a6f4416581df46db
# Successfully built libarchive
# ...

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %%
# !pip install cartopy
import cartopy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 64.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Initialize Prompt Template for Dynamic Interaction

# %%
from langchain_core.prompts import MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# Create a prompt template using MessagesPlaceholder for the question
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are an intelligent chatbot. Answer the following question."),
        MessagesPlaceholder(variable_name="question")
    ]
)

# %%
# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
question = "My name is Chamara. What is my name?"
response = chain.invoke({"questions": [HumanMessage(content=question)]})
print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-8aacd66cd39a> in <cell line: 0>()
#       1 question = "My name is Chamara. What is my name?"
# ----> 2 response = chain.invoke({"questions": [HumanMessage(content=question)]})
#       3 print(response)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3021                 with set_config_context(config) as context:
#    3022                     if i == 0:
# -> 3023                         input = context.run(step.invoke, input, config, **kwargs)
#    3024                     else:
#    3025                         input = context.run(step.invoke, input, config)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/prompts/base.py in invoke(self, input, config, **kwargs)
#     208         if self.tags:
# ...

# %% [markdown]
# Initialize Prompt Template with Predefined Conversation History

# %%
# Create a prompt template with a predefined conversation history and a new question placeholder
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are an intelligent chatbot. Answer the following question."),
        HumanMessage(content="My name is Chamara"),
        AIMessage(content="Nice to meet you Chamara"),
        MessagesPlaceholder(variable_name="question")
    ]
)

# %%
# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
question = "What is my name?"
response = chain.invoke({"question": [HumanMessage(content=question)]})
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-41-04301f630948> in <cell line: 0>()
#       1 question = "What is my name?"
# ----> 2 response = chain.invoke({"question": [HumanMessage(content=question)]})
#       3 print(response)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3023                         input = context.run(step.invoke, input, config, **kwargs)
#    3024                     else:
# -> 3025                         input = context.run(step.invoke, input, config)
#    3026         # finish the root run
#    3027         except BaseException as e:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     305         return cast(
#     306             ChatGeneration,
# ...

# %% [markdown]
# Initialize Promt Template to Handle Dynamic Conversation History

# %%
# Create a prompt template with a dynamic conversation history and a new question placeholder
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are an intelligent chatbot. Answer the following question."),
        MessagesPlaceholder(variable_name="history"),
        MessagesPlaceholder(variable_name="question")
    ]
)

# %%
# Define the conversation history
history = [
    HumanMessage(content="My name is Chamara"),
    AIMessage(content="Nice to meet you Chamara! How can I help you?"),
    HumanMessage(content="What is 2 + 2?"),
    AIMessage(content="4")
]

# %%
# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
question = "Who am I"
response = chain.invoke({"history": history, "question": [HumanMessage(content=question)]})
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-50-4a9784ede9b4> in <cell line: 0>()
#       1 question = "Who am I"
# ----> 2 response = chain.invoke({"history": history, "question": [HumanMessage(content=question)]})
#       3 print(response)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3023                         input = context.run(step.invoke, input, config, **kwargs)
#    3024                     else:
# -> 3025                         input = context.run(step.invoke, input, config)
#    3026         # finish the root run
#    3027         except BaseException as e:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     305         return cast(
#     306             ChatGeneration,
# ...

# %% [markdown]
# Update and Display Conversation History

# %%
history

[
    HumanMessage(content='My name is Chamara'),
    AIMessage(content='Nice to meet you Chamara! How can I help you?'),
    HumanMessage(content='What is 2 + 2?'),
    AIMessage(content='4'),
]
# Out:
# [HumanMessage(content='My name is Chamara', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Nice to meet you Chamara! How can I help you?', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What is 2 + 2?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='4', additional_kwargs={}, response_metadata={})]

# %%
# Extend the history with the latest question and response
history.extend([HumanMessage(content=question),
                AIMessage(content=response)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-c27afbd73dac> in <cell line: 0>()
#       1 # Extend the history with the latest question and response
#       2 history.extend([HumanMessage(content=question),
# ----> 3                 AIMessage(content=response)])
#
# NameError: name 'response' is not defined

# %%
history
# Out:
# [HumanMessage(content='My name is Chamara', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Nice to meet you Chamara! How can I help you?', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What is 2 + 2?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='4', additional_kwargs={}, response_metadata={})]

# %%
# Display the last four interactions in the conversation history
history[-4:]
# Out:
# [HumanMessage(content='My name is Chamara', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Nice to meet you Chamara! How can I help you?', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What is 2 + 2?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='4', additional_kwargs={}, response_metadata={})]

# %%
# !git config --global user.name "MSCPerera"
# !git config --global user.email "sandunperera200127@gmail.com"

# %%
# !git clone https://github.com/MSCPerera/ChatBot.git
# Out:
# Cloning into 'ChatBot'...
# fatal: could not read Username for 'https://github.com': No such device or address
